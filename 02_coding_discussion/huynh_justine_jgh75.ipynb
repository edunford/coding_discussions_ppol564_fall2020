# %%
### Start Of Justine's Insanity
### @author jghuynh
### A homework assignment that reads Covid cases data and practices 
### writing functions to get information about Covid in the States
#NotebookApp.rate_limit_window=15.0

# Initialize the "Index"
myMap = dict()
def add(row):
    """
    Adds a row of data into the Map
    This was hella stupid. I can't believe I wasted 3 hours doing this.
    
    @param row the row of data--contains date, state, cases, deaths
    
    """
    
    date = row[0]
    state = row[1]
    cases = int(row[3])
    deaths = int(row[4])

    if state in myMap:
        if date in myMap[state]:
            # if date and state are in the map
            # then just update the case and death
            myMap[state][date][0] += cases
            myMap[state][date][1] += deaths
        # But if date is not in map, but state is
        else:
            # Spawn a list for date
            dateCase = {date: [cases, deaths]}
            myMap[state][date] = [cases, deaths]
    else: 
        # If neither state nor date is there...
        myMap[state] = {date: [cases, deaths]}
        
# Reading the data
import csv
myMap = dict()
# open the file
with open('us-states.csv') as file:
    # Spawn an empty list
    stateCovidData = []
    # For ever row in the csv
    for row in csv.reader(file):
        # Append the row to the list
        stateCovidData.append(row)

        # Because I want to start adding rows after I pass the columns row
        # of ["date", "state", "fips", "cases", "deaths"]

        # A random side project for Justine's ridiculous insanity
        # Feel free to comment out this if-statement
        if "state" not in row:
            add(row)

len(stateCovidData)
# Out:
# 10080

# %%
### Actual Homework Part

## 1. Count up the unique dates in the data

def getNumUniqueDates(nestedList):
    """
    Gets the number of unique dates from the Covid data
    
    @param nestedList the data, in the form of a nested list
    @return the number of unique dates
    """
    
    uniqueDates = set()
    # For every row in nestedList
    # Start at row = 1 because row = 0 is the variable names
    for row in nestedList[1:]:
        uniqueDates.add(row[0])
    return uniqueDates

uniqueDates = getNumUniqueDates(stateCovidData)
print("There are", len(uniqueDates), "unique dates.")

## 2. Find the first date in which the District of Columbia recorded a case.

def getFirstDate(state, nestedList = stateCovidData):
    """
    Gets the first date where the given state had its first Covid case
    
    @param state the state
    @param nestedList the data, in the form of a nested list
    @return the first date of its first Covid case or -1 if state not found
    """
    
    firstDate = 0
    for row in nestedList:
        #print(row)
        if state in row:
            #print(row)
            firstDate = row[0]
            return firstDate
    return -1

print("District of Columbia's first date with Covid:", getFirstDate("District of Columbia", stateCovidData))

## 3. Write a function that takes in a state name as input (e.g. "Wisconsin") and outputs the date of its first case.

print("Wisconsin's First date with Covid:", getFirstDate("Wisconsin"))
    

## Optional Bonus Write a function that takes in a state name as input (e.g. "Wisconsin") 
## and outputs the date when the number of reported cases within the state exceeded 1000.


def firstTo1000(state, nestedList = stateCovidData):
    """
    Gets the date when a given state has at least 1000 Covid cases
    
    @param state the specified state
    @param nestedList Covid data by default, or any other data if specified
    @return the date when the state has at least 1000 Covid cases
    """

    myMap = dict()
    # For every row in the data
    for row in nestedList[1:]:
        date = row[0]
        place = row[1]
        numCases = int(row[3])
        if place not in myMap:
            myMap[place] = numCases
        else:
            myMap[place] =+ numCases
    
        # If the specified state is in the map
        if state in myMap:
            # check if state has more than 1000 cases
            if myMap[state] > 1000:
                # return the current date
                return date
        
        # another method to check if we got to 1000
print("Date when Wisconsin got at least 1000 cases:", firstTo1000("Wisconsin"))
# Out:
# There are 225 unique dates.
# District of Columbia's first date with Covid: 2020-03-07
# Wisconsin's First date with Covid: 2020-02-05
# Date when Wisconsin got at least 1000 cases: 2020-03-28

# %%
# This is so stupid and uneccessary
print(myMap)
# Out:
# {'Washington': {'2020-01-21': [1, 0], '2020-01-22': [1, 0], '2020-01-23': [1, 0], '2020-01-24': [1, 0], '2020-01-25': [1, 0], '2020-01-26': [1, 0], '2020-01-27': [1, 0], '2020-01-28': [1, 0], '2020-01-29': [1, 0], '2020-01-30': [1, 0], '2020-01-31': [1, 0], '2020-02-01': [1, 0], '2020-02-02': [1, 0], '2020-02-03': [1, 0], '2020-02-04': [1, 0], '2020-02-05': [1, 0], '2020-02-06': [1, 0], '2020-02-07': [1, 0], '2020-02-08': [1, 0], '2020-02-09': [1, 0], '2020-02-10': [1, 0], '2020-02-11': [1, 0], '2020-02-12': [1, 0], '2020-02-13': [1, 0], '2020-02-14': [1, 0], '2020-02-15': [1, 0], '2020-02-16': [1, 0], '2020-02-17': [1, 0], '2020-02-18': [1, 0], '2020-02-19': [1, 0], '2020-02-20': [1, 0], '2020-02-21': [1, 0], '2020-02-22': [1, 0], '2020-02-23': [1, 0], '2020-02-24': [5, 0], '2020-02-25': [5, 0], '2020-02-26': [5, 0], '2020-02-27': [5, 0], '2020-02-28': [7, 0], '2020-02-29': [10, 1], '2020-03-01': [17, 3], '2020-03-02': [23, 6], '2020-03-03': [32, 10], '2020-03-04': [47, 11], '2020-03-05': [75, 11], '2020-03-06': [86, 12], '2020-03-07': [110, 16], '2020-03-08': [141, 19], '2020-03-09': [179, 22], '2020-03-10': [279, 24], '2020-03-11': [338, 29], '2020-03-12': [419, 32], '2020-03-13': [511, 37], '2020-03-14': [609, 40], '2020-03-15': [675, 42], '2020-03-16': [794, 48], '2020-03-17': [908, 54], '2020-03-18': [1026, 68], '2020-03-19': [1228, 75], '2020-03-20': [1404, 83], '2020-03-21': [1655, 95], '2020-03-22': [1844, 97], '2020-03-23': [2101, 110], '2020-03-24': [2469, 123], '2020-03-25': [2585, 130], '2020-03-26': [3208, 152], '2020-03-27': [3770, 179], '2020-03-28': [4311, 193], '2020-03-29': [4897, 209], '2020-03-30': [5180, 221], '2020-03-31': [5293, 226], '2020-04-01': [5589, 250], '2020-04-02': [6586, 272], '2020-04-03': [6967, 293], '2020-04-04': [7499, 318], '2020-04-05': [7985, 344], '2020-04-06': [8385, 383], '2020-04-07': [8683, 409], '2020-04-08': [9098, 430], '2020-04-09': [9609, 456], '2020-04-10': [9888, 483], '2020-04-11': [10227, 498], '2020-04-12': [10414, 511], '2020-04-13': [10547, 525], '2020-04-14': [10711, 552], '2020-04-15': [10806, 572], '2020-04-16': [11180, 588], '2020-04-17': [11479, 610], '2020-04-18': [11850, 629], '2020-04-19': [11864, 637], '2020-04-20': [12255, 661], '2020-04-21': [12410, 683], '2020-04-22': [12606, 696], '2020-04-23': [12981, 717], '2020-04-24': [13197, 731], '2020-04-25': [13565, 743], '2020-04-26': [13744, 757], '2020-04-27': [13958, 771], '2020-04-28': [14165, 792], '2020-04-29': [14490, 805], '2020-04-30': [14814, 822], '2020-05-01': [15134, 829], '2020-05-02': [15383, 833], '2020-05-03': [15943, 840], '2020-05-04': [16047, 846], '2020-05-05': [16234, 863], '2020-05-06': [16873, 881], '2020-05-07': [17187, 903], '2020-05-08': [17477, 915], '2020-05-09': [17629, 925], '2020-05-10': [17781, 939], '2020-05-11': [18172, 957], '2020-05-12': [18382, 972], '2020-05-13': [18492, 977], '2020-05-14': [18861, 991], '2020-05-15': [19131, 1008], '2020-05-16': [19336, 1015], '2020-05-17': [19514, 1016], '2020-05-18': [19756, 1020], '2020-05-19': [19988, 1042], '2020-05-20': [20110, 1045], '2020-05-21': [20280, 1054], '2020-05-22': [20526, 1061], '2020-05-23': [20740, 1062], '2020-05-24': [20989, 1069], '2020-05-25': [21265, 1076], '2020-05-26': [21538, 1091], '2020-05-27': [21825, 1106], '2020-05-28': [22091, 1116], '2020-05-29': [22377, 1120], '2020-05-30': [22618, 1126], '2020-05-31': [22814, 1126], '2020-06-01': [23272, 1133], '2020-06-02': [23608, 1139], '2020-06-03': [23776, 1145], '2020-06-04': [23999, 1150], '2020-06-05': [24546, 1160], '2020-06-06': [24767, 1163], '2020-06-07': [25064, 1163], '2020-06-08': [25593, 1168], '2020-06-09': [25796, 1181], '2020-06-10': [25940, 1183], '2020-06-11': [26172, 1198], '2020-06-12': [26576, 1207], '2020-06-13': [26920, 1216], '2020-06-14': [27135, 1220], '2020-06-15': [27577, 1223], '2020-06-16': [27949, 1234], '2020-06-17': [28270, 1229], '2020-06-18': [28663, 1246], '2020-06-19': [29045, 1258], '2020-06-20': [29466, 1268], '2020-06-21': [297 ...
